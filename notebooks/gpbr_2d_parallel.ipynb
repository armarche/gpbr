# %%
import sys
import os
sys.path.append(os.path.abspath('..'))  # or the full path to the "project" directory
import numpy as np
import gpbr

# %%
def r1(s):
    return 0.45*np.sqrt(np.cos(s)**2 + np.sin(s)**2/4)

# def r1(s):
#     return (1+0.9*np.cos(s) + 0.1*np.sin(2*s))/(2+1.5*np.cos(s))

def r2(s):
    return (np.cos(s)**10+np.sin(s)**10)**(-0.1)

def dr2(s):
    term1 = (np.cos(s)**10 + np.sin(s)**10)**(-1.1)
    term2 = np.cos(s) * np.sin(s) * (np.sin(s)**8 - np.cos(s)**8)
    return -1.0 * term1 * term2

# def r2(s):
#     return np.ones_like(s)*0.8


# def dr2(s):
#     return np.zeros_like(s)

# %%
from gpbr.direct.common.boundary import Point3D
def f1(X, t: float) -> float:
    return np.zeros_like(X[0])

def f2(X, t: float) -> float:
    return np.ones_like(X[0]) ## TODO: Add time dependence

# %%
from gpbr.direct.heat_equation.common import MFSConfig2D
T = 1 # final time
N = 7 # N+1=10 time points
# M = 16 # number of collocation and points
M = 32 # number of collocation and points
ETA1 = 0.5
ETA2 = 2.0
config = MFSConfig2D(
    N=N,
    n_coll=M,
    n_source=M,
    T=T,
    eta1=ETA1,
    eta2=ETA2,
    f1=f1,
    f2=f2
)

# %%
from gpbr.direct.heat_equation.helpers import precalculate_mfs_data
mfs_data = precalculate_mfs_data(config)

# %%
from gpbr.direct.common.boundary import StarlikeCurve
Gamma2 = StarlikeCurve.from_radial_with_derivative(mfs_data.collocation, r2, dr2)
Gamma2_source = StarlikeCurve.from_radial(mfs_data.source_collocation, r2)

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

from gpbr.direct.common.boundary import StarlikeCurve

def plot_with_normals(Gamma: StarlikeCurve, normal_scale=0.2, show_points=True):
    """
    Plot a 2D starlike curve with its normal vectors.
    
    Parameters:
    -----------
    Gamma : StarlikeCurve
        The curve to plot.
    normal_scale : float, optional
        Scaling factor for normal vector length.
    show_points : bool, optional
        Whether to display points along the curve.
    """
    fig, ax = plt.subplots(figsize=(10, 8))
    
    # Extract coordinates
    x, y =  Gamma.points_np
    
    # Plot the curve
    ax.plot(x, y, 'b-', linewidth=2, label='Curve')
    
    # Plot points if requested
    if show_points:
        ax.plot(x, y, 'bo', markersize=4, alpha=0.5)

    nx, ny = Gamma.normals_np
    ax.quiver(x, y, nx/10, ny/10, color='red', scale=normal_scale,
                angles='xy', scale_units='xy', width=0.001,
                headwidth=10, headlength=10)
    
    # Set axis limits with padding
    all_x, all_y = Gamma.points_np
    max_extent = max(max(all_x) - min(all_x), max(all_y) - min(all_y))
    padding = max_extent * 0.5
    
    ax.set_xlim([min(all_x) - padding, max(all_x) + padding])
    ax.set_ylim([min(all_y) - padding, max(all_y) + padding])
    
    # Set equal aspect ratio to properly visualize angles
    ax.set_aspect('equal')
    
    # Add grid and labels
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.set_xlabel('X', fontsize=12)
    ax.set_ylabel('Y', fontsize=12)
    ax.set_title('Curve with Normal Vectors', fontsize=14)
    
    plt.tight_layout()
    plt.show()
    
    return fig, ax

import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

def plot_g1(G1, title="Starlike Curve", show_normals=False, color='#1f77b4', 
            figsize=(10, 8), dpi=120, save_path=None):
    """
    Plot a starlike curve with enhanced visual presentation.
    
    Parameters:
    -----------
    G1 : StarlikeCurve
        The starlike curve to plot.
    title : str, optional
        Title for the plot.
    show_normals : bool, optional
        Whether to display normal vectors.
    color : str, optional
        Color for the curve.
    figsize : tuple, optional
        Figure size (width, height) in inches.
    dpi : int, optional
        Resolution of the figure.
    save_path : str, optional
        If provided, save the figure to this path.
    """
    # Set up the figure with clean style
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, ax = plt.subplots(figsize=figsize, dpi=dpi)
    
    # Get points and plot with enhanced styling
    g1_x, g1_y = G1.points_np
    
    # Plot filled curve with fade
    ax.fill(g1_x, g1_y, color=color, alpha=0.2)
    
    # Plot curve with solid color instead of gradient
    ax.plot(g1_x, g1_y, color=color, linewidth=2.5, alpha=0.8)
    
    # Add a few markers along the curve
    num_markers = 12
    marker_indices = np.linspace(0, len(g1_x)-1, num_markers, dtype=int)
    ax.plot(g1_x[marker_indices], g1_y[marker_indices], 'o', color='navy', 
            markersize=5, alpha=0.8)

    # Enhance the appearance
    ax.set_aspect('equal')
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.set_title(title, fontsize=16, pad=15)
    ax.set_xlabel('X', fontsize=14)
    ax.set_ylabel('Y', fontsize=14)
    
    
    # Calculate max radius for setting limits
    max_radius = max(np.sqrt(g1_x**2 + g1_y**2))
    
    # Adjust limits with padding
    padding = max_radius * 0.1
    ax.set_xlim([-max_radius-padding, max_radius+padding])
    ax.set_ylim([-max_radius-padding, max_radius+padding])
    
    # Tight layout
    plt.tight_layout()
    
    # Save if a path is provided
    if save_path:
        plt.savefig(save_path, dpi=dpi, bbox_inches='tight')
    
    plt.show()
    
    return fig, ax

# %%
plot_with_normals(Gamma2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (<Figure size 1000x800 with 1 Axes>,
#  <Axes: title={'center': 'Curve with Normal Vectors'}, xlabel='X', ylabel='Y'>)

# %%
G1_plot = StarlikeCurve.from_radial(mfs_data.collocation, r1)
plot_g1(G1_plot)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (<Figure size 1200x960 with 1 Axes>,
#  <Axes: title={'center': 'Starlike Curve'}, xlabel='X', ylabel='Y'>)

# %%
from gpbr.direct.common.source import SourcePoints2D
from gpbr.direct.heat_equation.fundamental_sequence import FundamentalSequenceCoefs, matfundamental_sequence_2d
from gpbr.direct.heat_equation.helpers import form_fs_matrix, matdbu_2d, matform_fs_vector_2d

from numpy.linalg import lstsq


def eval_for_g1(
        Gamma2: StarlikeCurve,
        Gamma2_source: StarlikeCurve,
        f1, f2,
        mfs_data,
        r1_func
    ):
    Gamma1 = StarlikeCurve.from_radial(mfs_data.collocation, r1_func)
    Gamma1_source = StarlikeCurve.from_radial(mfs_data.source_collocation, r1_func)
    source_points = SourcePoints2D(Gamma1_source.collocation.n+Gamma2_source.collocation.n, mfs_data.eta1, mfs_data.eta2, Gamma1_source, Gamma2_source)


    fundamental_sequence_gamma1 = matfundamental_sequence_2d(Gamma1, source_points, mfs_data)
    fundamental_sequence_gamma2 = matfundamental_sequence_2d(Gamma2, source_points, mfs_data)
    PHI_MAT = form_fs_matrix(fundamental_sequence_gamma1, fundamental_sequence_gamma2)

    alpha_coeeff = np.empty((mfs_data.N+1, mfs_data.M), dtype=np.float64)
    alpha_coeeff[:] = np.nan
    fs_coefs = FundamentalSequenceCoefs(alpha_coeeff)
    for n in range(0, mfs_data.N+1):
        F = matform_fs_vector_2d(n,
                            fundamental_sequence_gamma1,
                            fundamental_sequence_gamma2,
                            Gamma1,
                            Gamma2,
                            fs_coefs,
                            f1, f2, mfs_data)
        try:
            alpha_n = lstsq(PHI_MAT, F)[0]
        except np.linalg.LinAlgError:
            print("Failed to solve the linear system")
            return None
        fs_coefs.alpha[n] = alpha_n.T

    du_vals = np.empty((mfs_data.N+1, mfs_data.M), dtype=np.float64)
    du_vals[:] = np.nan

    for ni in range(0, N+1):
        du_vals[ni] = matdbu_2d(Gamma2.points_np, Gamma2.normals_np, ni, source_points, fs_coefs, mfs_data).ravel()
    return du_vals

# %%
from gpbr.tools.noise import noise
exact_heat_flux = eval_for_g1(Gamma2, Gamma2_source, f1, f2, mfs_data, r1)
heat_flux = noise(exact_heat_flux, 0.05, seed=589993150)
# heat_flux = exact_heat_flux

# %%
heat_flux
# Out:
# array([[ 4.08757569e+00,  3.80498158e+00,  3.41267898e+00,
#          1.99182586e+00,  3.36932482e+00,  3.94684926e+00,
#          3.77554930e+00,  4.02201643e+00,  4.00582181e+00,
#          3.60249156e+00,  3.48194103e+00,  1.93713414e+00,
#          3.27485440e+00,  3.83595931e+00,  4.01104162e+00,
#          4.02309283e+00,  3.95565731e+00,  3.92562533e+00,
#          3.28196186e+00,  1.93013933e+00,  3.33997038e+00,
#          3.66103283e+00,  4.11481292e+00,  3.86231699e+00,
#          3.79121641e+00,  3.93258194e+00,  3.46428491e+00,
#          1.89082014e+00,  3.45219713e+00,  3.94118513e+00,
#          4.12358903e+00,  4.22745654e+00],
#        [ 4.73708005e-02, -1.18048340e-01, -9.20883931e-01,
#         -7.39591595e-01, -9.28407258e-01, -1.95083745e-01,
#         -1.09034733e-01, -1.85840250e-01, -1.08736805e-01,
#         -2.03150753e-01, -9.59369605e-01, -7.21423500e-01,
#         -9.13912618e-01, -1.28590989e-01,  5.02601295e-02,
#          1.44681287e-03,  5.08940845e-02, -1.21082165e-01,
#         -8.98929691e-01, -7.06013021e-01, -8.98498432e-01,
#         -1.99630418e-01, -1.03942239e-01, -1.89749900e-01,
#         -1.06831434e-01, -2.04173855e-01, -9.46300577e-01,
#         -7.58528282e-01, -8.81850084e-01, -1.28600967e-01,
#          5.13753517e-02,  1.41932227e-03],
#        [ 2.19068962e+00,  1.78974343e+00,  1.72869188e+00,
#          8.83724607e-01,  1.68821662e+00,  1.63098661e+00,
#          1.97807129e+00,  2.24430796e+00,  1.91189025e+00,
#          1.54415588e+00,  1.80502788e+00,  8.57543934e-01,
#          1.66402654e+00,  1.63180500e+00,  2.24895482e+00,
#          2.46898421e+00,  2.25431883e+00,  1.73875700e+00,
#          1.79029580e+00,  8.92416626e-01,  1.74583688e+00,
#          1.56628609e+00,  1.91701091e+00,  2.31315101e+00,
#          1.93652174e+00,  1.63284964e+00,  1.77045189e+00,
#          8.78614980e-01,  1.66480645e+00,  1.63772577e+00,
#          2.18248151e+00,  2.67809566e+00],
#        [ 4.38316460e-01,  4.45659282e-01, -5.70546644e-01,
#         -3.28675807e-01, -5.96208371e-01,  2.91781963e-01,
#          1.94599357e-01, -2.29605674e-02,  1.91414530e-01,
#          2.86747663e-01, -5.87606331e-01, -3.31275694e-01,
#         -5.78078445e-01,  4.21216980e-01,  4.31137744e-01,
#          2.78136830e-01,  4.47769833e-01,  4.33557667e-01,
#         -5.64590120e-01, -3.16546035e-01, -5.98613952e-01,
#          2.75795997e-01,  2.01106521e-01, -2.29969898e-02,
#          2.09432810e-01,  2.80721761e-01, -6.07086855e-01,
#         -3.09463608e-01, -5.40609062e-01,  4.38582548e-01,
#          4.55613141e-01,  2.85618131e-01],
#        [ 2.01473791e+00,  1.37534762e+00,  1.54816385e+00,
#          6.04636904e-01,  1.56468644e+00,  1.25568008e+00,
#          1.85529068e+00,  2.15129832e+00,  1.69123863e+00,
#          1.19160682e+00,  1.60742835e+00,  6.16053362e-01,
#          1.56497395e+00,  1.34737099e+00,  2.02990670e+00,
#          2.36149931e+00,  2.09872253e+00,  1.38829393e+00,
#          1.54722436e+00,  5.90723491e-01,  1.60169142e+00,
#          1.23432908e+00,  1.69731085e+00,  2.20566972e+00,
#          1.72762260e+00,  1.23911483e+00,  1.61438097e+00,
#          6.04699290e-01,  1.50353270e+00,  1.43753460e+00,
#          2.07485635e+00,  2.41991166e+00],
#        [ 6.11543787e-01,  6.67394413e-01, -4.30992075e-01,
#         -1.49510964e-01, -4.47706629e-01,  5.26063285e-01,
#          3.60947432e-01,  6.33681327e-02,  3.72797379e-01,
#          5.15954515e-01, -4.67817619e-01, -1.39629995e-01,
#         -4.24395847e-01,  6.47133824e-01,  6.07615479e-01,
#          3.73155362e-01,  6.38346683e-01,  7.01010371e-01,
#         -4.25223035e-01, -1.45003927e-01, -4.42179480e-01,
#          5.48074642e-01,  3.68689454e-01,  6.33204663e-02,
#          3.77559631e-01,  5.31348650e-01, -4.49468813e-01,
#         -1.40769983e-01, -4.20512013e-01,  6.59888980e-01,
#          5.87552575e-01,  3.48770787e-01],
#        [ 1.97330620e+00,  1.14504188e+00,  1.43377871e+00,
#          4.70412249e-01,  1.40880350e+00,  1.00973723e+00,
#          1.70063231e+00,  2.19408907e+00,  1.65776121e+00,
#          1.03318838e+00,  1.48882010e+00,  4.65524716e-01,
#          1.46339763e+00,  1.25123870e+00,  1.93031978e+00,
#          2.39244582e+00,  1.97710840e+00,  1.19055962e+00,
#          1.41743143e+00,  4.67212339e-01,  1.47561582e+00,
#          1.05346907e+00,  1.56692430e+00,  2.14980825e+00,
#          1.59578839e+00,  1.05138225e+00,  1.42420343e+00,
#          4.55486630e-01,  1.52166034e+00,  1.22510924e+00,
#          1.90073912e+00,  2.48217291e+00],
#        [ 7.12993252e-01,  8.51192112e-01, -3.62114336e-01,
#         -5.94097491e-02, -3.95529830e-01,  7.10577998e-01,
#          4.73965202e-01,  1.12795670e-01,  4.71775915e-01,
#          6.66685945e-01, -3.78422503e-01, -5.72754776e-02,
#         -3.59718434e-01,  8.08996594e-01,  6.88553133e-01,
#          4.17521680e-01,  7.08086643e-01,  8.37429527e-01,
#         -3.67508355e-01, -5.59365251e-02, -3.97494196e-01,
#          7.05574097e-01,  4.82690081e-01,  1.16003640e-01,
#          4.52950092e-01,  6.56899740e-01, -4.05380320e-01,
#         -5.65262513e-02, -3.63573966e-01,  7.77745169e-01,
#          6.95481076e-01,  3.89090837e-01]])

# %% [markdown]
# ## Fitness calculation

# %%
from scipy import integrate
def calc_l2_norm(ncoll, thetas, tn, exact, approx):
    diff_squared = (approx - exact) ** 2
    # First integrate over theta for each time
    theta_integrals = integrate.trapezoid(diff_squared, thetas, axis=1)
    # Then integrate the result over time
    total_integral = integrate.trapezoid(theta_integrals, tn)
    return total_integral

# %%
def feasable(ext_boundary_vals, rfunc, rvals):
    # Not closed curve
    if abs(rfunc(0) - rfunc(2*np.pi)) > 1e-10:
        return False

    if not np.isfinite(rvals).all():
        return False

    # Singularities
    if np.any(np.less_equal(rvals, 1e-5)):
        return False

    # Exceeds the outer boundary
    if np.any(np.greater_equal(rvals, ext_boundary_vals)):
        return False
    
    return True

# %%
def evaluate(mfsd, tlb, ind):
    ind_compile = tlb.compile(expr=ind)
    ind_values = ind_compile(mfsd.collocation.theta)
    if not tlb.feasable(ind_compile, ind_values):
        return (1e6, )

    g2_approx = tlb.calc_normals(ind_compile)
    if g2_approx is None:
        print("Failed to calculate g2_approx for individual :", ind)
        return (1e6, )
    
    if ind_values.shape == ():
        ind_values = np.ones_like(mfsd.collocation.theta) * ind_values
    return (tlb.norm(g2_approx) + integrate.trapezoid(ind_values**2, mfsd.collocation.theta, axis=0)*1e-4, )

# %% [markdown]
# ### Primitive set

# %%
from deap import gp
from gpbr.gp.funcs import pow2, sqrtabs, expplusone

pset = gp.PrimitiveSet("main", 1)
pset.addPrimitive(np.add, 2)
# pset.addPrimitive(np.subtract, 2)
pset.addPrimitive(np.multiply, 2)
pset.addPrimitive(np.cos, 1)
pset.addPrimitive(np.sin, 1)
pset.addPrimitive(sqrtabs, 1)
# pset.addPrimitive(pow2, 1)
pset.addPrimitive(expplusone, 1)
pset.addEphemeralConstant('rand', (np.random.rand, 1)[0])
# pset.addTerminal(np.pi, 'pi')

pset.renameArguments(ARG0="s")

# %% [markdown]
# ### Individual representation

# %%
from deap import creator, base, tools, algorithms
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMin)

# %% [markdown]
# ### Toolbox compiling

# %%
toolbox = base.Toolbox()
toolbox.register('expr', gp.genHalfAndHalf, pset=pset, min_=3, max_=6)
toolbox.register('individual', tools.initIterate, creator.Individual, toolbox.expr)
toolbox.register('population', tools.initRepeat, list, toolbox.individual)
toolbox.register('compile', gp.compile, pset=pset)

# %%
toolbox.register('feasable', feasable, Gamma2.rf(mfs_data.collocation.theta))
toolbox.register('calc_normals', eval_for_g1, Gamma2, Gamma2_source, f1, f2, mfs_data)
toolbox.register('norm', calc_l2_norm, mfs_data.M, mfs_data.collocation.theta, mfs_data.tn, heat_flux)
# toolbox.register('evaluate', evaluate, mfs_data, toolbox)

# %% [markdown]
# ### Selection

# %%
toolbox.register("select", tools.selTournament, tournsize=3)
# toolbox.register("select", tools.selBest)
# toolbox.register("select", tools.selTournament, tournsize=4)
# toolbox.register("select", tools.selDoubleTournament, fitness_size=3, fitness_first=False, parsimony_size=1.4)
# toolbox.register("select", tools.selNSGA2)
# toolbox.register("select", tools.selLexicase)
# toolbox.register("select", tools.selAutomaticEpsilonLexicase)

# %% [markdown]
# ### Operators

# %%
import random
def random_operator(options):
    return random.choice(options)

# %%
import random
import operator

from gpbr.gp.operators import cxLinearCombination


toolbox.register("mate_onepoint", gp.cxOnePoint)
toolbox.register("mate_lincomb", cxLinearCombination, pset=pset)
toolbox.register("mate_leaf_based", gp.cxOnePointLeafBiased, termpb=0.35)
mate_operators = [toolbox.mate_lincomb, toolbox.mate_onepoint, toolbox.mate_leaf_based]

toolbox.register("expr_mut", gp.genHalfAndHalf, min_=0, max_=2)
toolbox.register("mutate_uniform", gp.mutUniform, expr=toolbox.expr_mut, pset=pset)
toolbox.register("mutate_node_replacement", gp.mutNodeReplacement, pset=pset)
toolbox.register("mutate_ephemeral", gp.mutEphemeral, mode="one")
toolbox.register("mutate_insert", gp.mutInsert, pset=pset)
toolbox.register("mutate_shrink", gp.mutShrink)
# toolbox.register("mutate_shift", mutate_angular_shift, pset=pset)
# toolbox.register("mutate_shrink", gp.mutShrink)
mutate_operators = [toolbox.mutate_uniform, toolbox.mutate_node_replacement, toolbox.mutate_ephemeral, toolbox.mutate_insert, toolbox.mutate_shrink]


toolbox.register("mate", random.choice(mate_operators))
toolbox.register("mutate", random.choice(mutate_operators))

# %% [markdown]
# ### Bloat control

# %%
# toolbox.decorate("mate", gp.staticLimit(key=operator.attrgetter("height"), max_value=8))
# toolbox.decorate("mutate", gp.staticLimit(key=operator.attrgetter("height"), max_value=8))

toolbox.decorate("mate", gp.staticLimit(key=operator.attrgetter("height"), max_value=17))
toolbox.decorate("mutate", gp.staticLimit(key=operator.attrgetter("height"), max_value=17))

# %%
def chunks(lst, n):
    k, m = divmod(len(lst), n)
    return [lst[i * k + min(i, m):(i + 1) * k + min(i + 1, m)] for i in range(n)]

toolbox.register("chunks", chunks, n=5)

# %%
from deap import gp
import ray
from scipy import integrate

@ray.remote
class Evaluator2D:
    def __init__(self, Gamma2, Gamma2_source, f1, f2, mfs_data, ext_boundary_vals, gp_pset, exact_heat_flux):
        self.ext_boundary_vals = ext_boundary_vals
        self.Gamma2 = Gamma2
        self.Gamma2_source = Gamma2_source
        self.f1 = f1
        self.f2 = f2
        self.mfs_data = mfs_data
        self.pset = gp_pset
        self.exact_heat_flux = exact_heat_flux
    
    def calculate_heat_flux(self, r1_func):
        Gamma1 = StarlikeCurve.from_radial(self.mfs_data.collocation, r1_func)
        Gamma1_source = StarlikeCurve.from_radial(self.mfs_data.source_collocation, r1_func)
        source_points = SourcePoints2D(
            Gamma1_source.collocation.n+Gamma2_source.collocation.n,
            self.mfs_data.eta1,
            self.mfs_data.eta2,
            Gamma1_source,
            self.Gamma2_source)


        fundamental_sequence_gamma1 = matfundamental_sequence_2d(Gamma1, source_points, self.mfs_data)
        fundamental_sequence_gamma2 = matfundamental_sequence_2d(Gamma2, source_points, self.mfs_data)
        PHI_MAT = form_fs_matrix(fundamental_sequence_gamma1, fundamental_sequence_gamma2)

        alpha_coeeff = np.empty((self.mfs_data.N+1, self.mfs_data.M), dtype=np.float64)
        alpha_coeeff[:] = np.nan
        fs_coefs = FundamentalSequenceCoefs(alpha_coeeff)
        for n in range(0, self.mfs_data.N+1):
            F = matform_fs_vector_2d(n,
                                fundamental_sequence_gamma1,
                                fundamental_sequence_gamma2,
                                Gamma1,
                                self.Gamma2,
                                fs_coefs,
                                self.f1, self.f2, self.mfs_data)
            try:
                alpha_n = lstsq(PHI_MAT, F)[0]
            except np.linalg.LinAlgError:
                print("Failed to solve the linear system")
                return None
            fs_coefs.alpha[n] = alpha_n.T

        du_vals = np.empty((self.mfs_data.N+1, self.mfs_data.M), dtype=np.float64)
        du_vals[:] = np.nan

        for ni in range(0, N+1):
            du_vals[ni] = matdbu_2d(self.Gamma2.points_np, self.Gamma2.normals_np, ni, source_points, fs_coefs, self.mfs_data).ravel()
        return du_vals

    def feasable(self, rfunc, rvals):
        # Not closed curve
        if abs(rfunc(0) - rfunc(2*np.pi)) > 1e-10:
            return False

        if not np.isfinite(rvals).all():
            return False

        # Singularities
        if np.any(np.less_equal(rvals, 1e-5)):
            return False

        # Exceeds the outer boundary
        if np.any(np.greater_equal(rvals, self.ext_boundary_vals)):
            return False
        
        return True

    def norm(self, approx):
        diff_squared = (approx - self.exact_heat_flux) ** 2
        # First integrate over theta for each time
        theta_integrals = integrate.trapezoid(diff_squared, self.mfs_data.collocation.theta, axis=1)
        # Then integrate the result over time
        total_integral = integrate.trapezoid(theta_integrals, self.mfs_data.tn)
        return total_integral

    def eval(self, individual):
        r1_func = gp.compile(expr=individual, pset=self.pset)
        r1_vals = r1_func(self.mfs_data.collocation.theta)
        if not self.feasable(r1_func, r1_vals):
            return (1e6, )
        # Calculate the heat flux
        du_vals = self.calculate_heat_flux(r1_func)
        if du_vals is None:
            print("Failed to calculate du_vals for individual :", individual)
            return (1e6, )
        # Calculate the norm
        if isinstance(r1_vals, float) or r1_vals.shape == ():
            r1_vals = np.ones_like(self.mfs_data.collocation.theta) * r1_vals
        
        return (self.norm(du_vals) + integrate.trapezoid(r1_vals**2, self.mfs_data.collocation.theta, axis=0)*1e-4,)

    def eval_batch(self, batch):
        return [self.eval(ind) for ind in batch]

# %%
from deap.algorithms import varOr
from itertools import chain

def eaMuPlusLambda(population, toolbox, mu, lambda_, cxpb, mutpb, ngen,
                   ray_evaluetors_pool,
                   stats=None, halloffame=None, verbose=__debug__):
    logbook = tools.Logbook()
    logbook.header = ['gen', 'nevals'] + (stats.fields if stats else [])

    # # Evaluate the individuals with an invalid fitness
    # invalid_ind = [ind for ind in population if not ind.fitness.valid]
    # batch_size = len(invalid_ind) // len(ray_actors)
    # for i, actor in enumerate(ray_actors):
    #     start = i * batch_size
    #     end = (i + 1) * batch_size if i < len(ray_actors) - 1 else len(invalid_ind)
    #     actor.set_individuals(invalid_ind[start:end])



    invalid_ind = [ind for ind in population if not ind.fitness.valid]
    # fitnesses = list(ray_evaluetors_pool.map(lambda evaluator, eval_ind: evaluator.eval.remote(eval_ind), invalid_ind))
    fitnesses = list(chain.from_iterable(ray_evaluetors_pool.map(lambda evaluator, chunk: evaluator.eval_batch.remote(chunk), toolbox.chunks(invalid_ind))))
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit
    

    # fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
    # for ind, fit in zip(invalid_ind, fitnesses):
    #     ind.fitness.values = fit

    if halloffame is not None:
        halloffame.update(population)

    record = stats.compile(population) if stats is not None else {}
    logbook.record(gen=0, nevals=len(invalid_ind), **record)
    if verbose:
        print(logbook.stream)

    # Begin the generational process
    for gen in range(1, ngen + 1):
        # Vary the population
        offspring = varOr(population, toolbox, lambda_, cxpb, mutpb)

        # # Evaluate the individuals with an invalid fitness
        # invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        # fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
        # for ind, fit in zip(invalid_ind, fitnesses):
        #     ind.fitness.values = fit

        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        # fitnesses = list(ray_evaluetors_pool.map(lambda evaluator, eval_ind: evaluator.eval.remote(eval_ind), invalid_ind))
        fitnesses = list(chain.from_iterable(ray_evaluetors_pool.map(lambda evaluator, chunk: evaluator.eval_batch.remote(chunk), toolbox.chunks(invalid_ind))))
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit

        # Update the hall of fame with the generated individuals
        if halloffame is not None:
            halloffame.update(offspring)

        # Select the next generation population
        population[:] = toolbox.select(population + offspring, mu)

        # Update the statistics with the new population
        record = stats.compile(population) if stats is not None else {}
        logbook.record(gen=gen, nevals=len(invalid_ind), **record)
        if verbose:
            print(logbook.stream)

    return population, logbook

# %%
import ray
ray.init(runtime_env={"working_dir": "/Users/armarche/armarche_phd/gpbr_backup"}) # Only call this once.
# Out:
# 2025-05-31 17:59:56,509	INFO worker.py:1879 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2025-05-31 17:59:56,635	INFO packaging.py:576 -- Creating a file package for local module '/Users/armarche/armarche_phd/gpbr_backup'.
# 2025-05-31 17:59:56,790	INFO packaging.py:368 -- Pushing file package 'gcs://_ray_pkg_299bc32379969272.zip' (46.59MiB) to Ray cluster...
# 2025-05-31 17:59:56,849	INFO packaging.py:381 -- Successfully pushed file package 'gcs://_ray_pkg_299bc32379969272.zip'.
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.12.6', ray_version='2.46.0', ray_commit='c3dd2ca0c2a24ddf327a213d2e936bd4eaa4ca0a')
# (pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/direct/heat_equation/helpers.py:154: SyntaxWarning: invalid escape sequence '\i'
# (pid=17084)   """
# (pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/direct/heat_equation/helpers.py:166: SyntaxWarning: invalid escape sequence '\i'
# (pid=17084)   """
# (pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/direct/heat_equation/helpers.py:179: SyntaxWarning: invalid escape sequence '\i'
# (pid=17084)   """
# (pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/direct/heat_equation/helpers.py:202: SyntaxWarning: invalid escape sequence '\i'
# (pid=17084)   """
# (pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/direct/heat_equation/helpers.py:214: SyntaxWarning: invalid escape sequence '\i'
# (pid=17084)   """
# (pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/direct/heat_equation/helpers.py:228: SyntaxWarning: invalid escape sequence '\i'
# (pid=17084)   """
# (pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/direct/heat_equation/helpers.py:245: SyntaxWarning: invalid escape sequence '\i'
# (pid=17084)   """
# (pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/direct/heat_equation/helpers.py:267: SyntaxWarning: invalid escape sequence '\i'
# (pid=17084)   """
# (Evaluator2D pid=17084) /tmp/ray/session_2025-05-31_17-59-55_006854_17046/runtime_resources/working_dir_files/_ray_pkg_299bc32379969272/gpbr/gp/funcs.py:47: RuntimeWarning: overflow encountered in exp
# (Evaluator2D pid=17084)   return np.exp(np.ones_like(x, dtype=np.float64) + x)
# (Evaluator2D pid=17084) <string>:1: RuntimeWarning: invalid value encountered in sin
# (Evaluator2D pid=17082) <string>:1: RuntimeWarning: invalid value encountered in cos
# (Evaluator2D pid=17082) /var/folders/yp/sztpn13x2vq42vlgbb1zx8b80000gn/T/ipykernel_17046/150319737.py:59: RuntimeWarning: invalid value encountered in scalar subtract

# %%
def get_evaluaror(Gamma2, Gamma2_source, f1, f2, mfs_data, pset, heat_flux):
    return Evaluator2D.remote(
        Gamma2,
        Gamma2_source,
        f1,
        f2,
        mfs_data,
        Gamma2.rf(mfs_data.collocation.theta),
        pset,
        heat_flux
    )

# %%
evaluators = [get_evaluaror(Gamma2, Gamma2_source, f1, f2, mfs_data, pset, heat_flux) for _ in range(5)]

# %%
evaluators_pool = ray.util.ActorPool(evaluators)

# %%
pop = toolbox.population(n=1000)
hof = tools.HallOfFame(1)

stats_fit = tools.Statistics(lambda ind: ind.fitness.values)
stats_size = tools.Statistics(len)
mstats = tools.MultiStatistics(fitness=stats_fit, size=stats_size)
mstats.register("avg", np.mean)
mstats.register("std", np.std)
mstats.register("min", np.min)
mstats.register("max", np.max)

# %%
# MU, LAMBDA = 100, 200
MU, LAMBDA = 500, 1000
pop, logbook = eaMuPlusLambda(pop, toolbox, mu=MU, lambda_=LAMBDA,
                                            cxpb=0.7, mutpb=0.3, ngen=100, 
                                            ray_evaluetors_pool=evaluators_pool,
                                            stats=mstats, halloffame=hof)
# Out:
#    	      	                       fitness                        	                     size
#    	      	------------------------------------------------------	----------------------------------------------
# gen	nevals	avg   	gen	max  	min      	nevals	std   	avg   	gen	max	min	nevals	std
# 0  	1000  	866027	0  	1e+06	0.0457111	1000  	340584	11.361	0  	56 	4  	1000  	7.5349
# 1  	1000  	622080	1  	1e+06	0.0457111	1000  	484785	9.706 	1  	56 	2  	1000  	7.06594
# 2  	1000  	344072	2  	1e+06	0.0458915	1000  	474989	8.144 	2  	43 	2  	1000  	5.92784
# 3  	1000  	84059.9	3  	1e+06	0.0456434	1000  	277370	6.352 	3  	38 	2  	1000  	4.12893
# 4  	1000  	4019.67	4  	1e+06	0.0456147	1000  	63117.8	5.95  	4  	20 	2  	1000  	3.42162
# 5  	1000  	5.12295	5  	955.438	0.0455998	1000  	53.7233	6.13  	5  	28 	2  	1000  	3.78749
# 6  	1000  	2000.92	6  	1e+06  	0.0455543	1000  	44676.6	6.186 	6  	25 	2  	1000  	3.80518
# 7  	1000  	0.595571	7  	39.1679	0.0455543	1000  	2.50781	6.14  	7  	25 	2  	1000  	3.98
# 8  	1000  	3.36939 	8  	1334.7 	0.0455526	1000  	59.7406	5.754 	8  	18 	2  	1000  	3.71557
# 9  	1000  	8.50942 	9  	2015.2 	0.0455543	1000  	124.525	5.722 	9  	22 	2  	1000  	3.90035
# 10 	1000  	4000.54 	10 	1e+06  	0.0299125	1000  	63118.9	5.554 	10 	26 	2  	1000  	3.91754
# 11 	1000  	4000.11 	11 	1e+06  	0.0299125	1000  	63118.9	5.664 	11 	26 	2  	1000  	4.25477
# 12 	1000  	5.24259 	12 	1713.8 	0.0299125	1000  	80.2289	5.44  	12 	26 	2  	1000  	4.11271
# 13 	1000  	0.122066	13 	11.488 	0.0299125	1000  	0.711644	5.378 	13 	26 	2  	1000  	4.40853
# 14 	1000  	2000.13 	14 	1e+06  	0.0299125	1000  	44676.6 	4.948 	14 	26 	2  	1000  	4.29945
# 15 	1000  	0.0829935	15 	8.42708	0.0299125	1000  	0.396992	4.432 	15 	26 	2  	1000  	4.16382
# 16 	1000  	2004.06  	16 	1e+06  	0.0299125	1000  	44676.5 	4.39  	16 	26 	2  	1000  	4.90692
# 17 	1000  	0.166606 	17 	43.101 	0.0264238	1000  	1.97072 	4.932 	17 	41 	2  	1000  	6.34818
# 18 	1000  	2001.85  	18 	1e+06  	0.0250317	1000  	44676.5 	5.552 	18 	26 	2  	1000  	6.91631
# 19 	1000  	0.11935  	19 	13.595 	0.0207271	1000  	0.689041	6.324 	19 	27 	2  	1000  	6.95119
# 20 	1000  	8000.08  	20 	1e+06  	0.0207271	1000  	89084.2 	7.08  	20 	26 	2  	1000  	7.36
# 21 	1000  	0.0846771	21 	5.66511	0.0207271	1000  	0.311677	8.12  	21 	28 	2  	1000  	8.02531
# 22 	1000  	2000.13  	22 	1e+06  	0.0207271	1000  	44676.6 	9.588 	22 	35 	2  	1000  	8.45992
# 23 	1000  	2000.59  	23 	1e+06  	0.0207271	1000  	44676.6 	11.278	23 	32 	2  	1000  	8.67599
# 24 	1000  	2003.01  	24 	1e+06  	0.0124318	1000  	44676.5 	13.62 	24 	39 	2  	1000  	8.63201
# 25 	1000  	0.0803794	25 	1.92977	0.0124318	1000  	0.178078	14.75 	25 	40 	2  	1000  	8.43845
# 26 	1000  	0.418297 	26 	169.337	0.0121083	1000  	7.56375 	16.766	26 	48 	2  	1000  	8.44673
# 27 	1000  	4001.19  	27 	1e+06  	0.0121083	1000  	63118.9 	18.172	27 	40 	2  	1000  	7.86755
# 28 	1000  	2.98304  	28 	1098.67	0.0121083	1000  	51.6451 	19.532	28 	43 	2  	1000  	7.37218
# 29 	1000  	1.12283  	29 	405.226	0.0121083	1000  	18.5489 	20.456	29 	61 	2  	1000  	7.62077
# 30 	1000  	4000.78  	30 	1e+06  	0.0119893	1000  	63118.9 	21.38 	30 	61 	2  	1000  	7.04185
# 31 	1000  	1.02375  	31 	224.149	0.0121083	1000  	11.4781 	21.812	31 	61 	2  	1000  	7.6504
# 32 	1000  	0.506355 	32 	224.149	0.0120506	1000  	10.0139 	22.252	32 	61 	2  	1000  	8.13416
# 33 	1000  	6000.59  	33 	1e+06  	0.0120506	1000  	77226.9 	23.514	33 	64 	4  	1000  	8.924
# 34 	1000  	4000.05  	34 	1e+06  	0.011391 	1000  	63118.9 	24.862	34 	64 	2  	1000  	8.74431
# 35 	1000  	4001.58  	35 	1e+06  	0.011391 	1000  	63118.8 	25.25 	35 	65 	2  	1000  	8.01246
# 36 	1000  	0.343331 	36 	99.5001	0.0106802	1000  	4.82556 	25.352	36 	66 	2  	1000  	7.33049
# 37 	1000  	0.152394 	37 	41.5042	0.0109375	1000  	1.99677 	24.714	37 	64 	2  	1000  	6.86558
# 38 	1000  	2000.18  	38 	1e+06  	0.0107771	1000  	44676.6 	26.484	38 	64 	6  	1000  	6.70893
# 39 	1000  	2000.23  	39 	1e+06  	0.0107771	1000  	44676.6 	27.328	39 	49 	5  	1000  	5.79728
# 40 	1000  	0.0282251	40 	5.91062	0.0106857	1000  	0.265377	28.06 	40 	49 	7  	1000  	5.53502
# 41 	1000  	2000.02  	41 	1e+06  	0.0106038	1000  	44676.6 	28.47 	41 	49 	5  	1000  	5.42854
# 42 	1000  	4.25677  	42 	2022.81	0.0106038	1000  	90.4721 	28.536	42 	50 	5  	1000  	4.80132
# 43 	1000  	4000.05  	43 	1e+06  	0.010555 	1000  	63118.9 	27.724	43 	50 	4  	1000  	4.91119
# 44 	1000  	0.0551748	44 	21.4268	0.010555 	1000  	0.956781	27.708	44 	50 	8  	1000  	4.74244
# 45 	1000  	1.32057  	45 	653.838	0.0105496	1000  	29.2107 	27.49 	45 	50 	6  	1000  	4.74909
# 46 	1000  	0.0114811	46 	0.152993	0.0105371	1000  	0.0068172	27.894	46 	50 	6  	1000  	4.84838
# 47 	1000  	0.199545 	47 	94.0188 	0.0105065	1000  	4.19993  	28.492	47 	43 	5  	1000  	5.26136
# 48 	1000  	0.0121799	48 	0.299268	0.0105065	1000  	0.0148589	28.632	48 	44 	6  	1000  	5.24448
# 49 	1000  	1.51372  	49 	750.958 	0.0105065	1000  	33.5497  	29.022	49 	44 	6  	1000  	5.1936
# 50 	1000  	2.79399  	50 	653.185 	0.0105065	1000  	41.3285  	29.722	50 	43 	2  	1000  	4.9312
# 51 	1000  	2000.11  	51 	1e+06   	0.0105065	1000  	44676.6  	30.624	51 	47 	7  	1000  	4.58068
# 52 	1000  	0.0116529	52 	0.131382	0.0105065	1000  	0.0091076	31.326	52 	44 	6  	1000  	4.88259
# 53 	1000  	0.0110627	53 	0.0582444	0.0105065	1000  	0.00372749	32.438	53 	44 	8  	1000  	4.42382
# 54 	1000  	0.01082  	54 	0.0386365	0.0105044	1000  	0.00155258	32.704	54 	46 	8  	1000  	4.09297
# 55 	1000  	0.0119172	55 	0.202078 	0.0104992	1000  	0.0117731 	32.166	55 	45 	6  	1000  	4.61546
# 56 	1000  	0.0802073	56 	34.1654  	0.0105044	1000  	1.52595   	32.21 	56 	59 	4  	1000  	4.56091
# 57 	1000  	0.0109794	57 	0.0553438	0.0105044	1000  	0.00346432	31.688	57 	47 	7  	1000  	3.94292
# 58 	1000  	0.0128375	58 	0.60293  	0.0105044	1000  	0.0296088 	31.522	58 	45 	7  	1000  	3.71127
# 59 	1000  	0.0109632	59 	0.0568694	0.0104989	1000  	0.00283521	31.132	59 	45 	6  	1000  	3.72915
# 60 	1000  	0.0114516	60 	0.170898 	0.0104989	1000  	0.00908373	30.86 	60 	45 	7  	1000  	3.01868
# 61 	1000  	2000.01  	61 	1e+06    	0.0104989	1000  	44676.6   	31    	61 	45 	11 	1000  	2.13448
# 62 	1000  	2000.08  	62 	1e+06    	0.0104989	1000  	44676.6   	30.856	62 	42 	4  	1000  	2.59524
# 63 	1000  	0.0118001	63 	0.321352 	0.01049  	1000  	0.0150125 	31.02 	63 	47 	8  	1000  	2.36381
# 64 	1000  	0.0113669	64 	0.149233 	0.01049  	1000  	0.00782043	31.102	64 	52 	8  	1000  	2.59915
# 65 	1000  	0.0108737	65 	0.0467824	0.01049  	1000  	0.00230871	30.904	65 	42 	6  	1000  	3.08525
# 66 	1000  	0.0141738	66 	0.749414 	0.01049  	1000  	0.047154  	31.084	66 	44 	6  	1000  	3.36941
# 67 	1000  	0.011217 	67 	0.11255  	0.01049  	1000  	0.00616512	31.384	67 	42 	8  	1000  	2.78578
# 68 	1000  	0.0123895	68 	0.319925 	0.01049  	1000  	0.0181508 	31.384	68 	41 	6  	1000  	3.37884
# 69 	1000  	0.0122667	69 	0.260631 	0.01049  	1000  	0.014749  	31.312	69 	41 	8  	1000  	3.3667
# 70 	1000  	0.0112827	70 	0.0976326	0.0104747	1000  	0.00512033	31.44 	70 	44 	9  	1000  	2.84577
# 71 	1000  	0.0121049	71 	0.222366 	0.0104747	1000  	0.0149062 	31.154	71 	41 	6  	1000  	2.94114
# 72 	1000  	0.0674966	72 	27.1343  	0.0104747	1000  	1.21187   	31.118	72 	42 	7  	1000  	3.40178
# 73 	1000  	0.0131128	73 	0.53143  	0.0104747	1000  	0.0278585 	31.436	73 	41 	7  	1000  	3.02091
# 74 	1000  	0.0113223	74 	0.14247  	0.0104667	1000  	0.00764382	31.74 	74 	41 	7  	1000  	3.34251
# 75 	1000  	0.010858 	75 	0.0490226	0.0104667	1000  	0.00252078	31.806	75 	43 	8  	1000  	3.50947
# 76 	1000  	0.0137754	76 	0.348273 	0.0104667	1000  	0.0278309 	32.024	76 	42 	7  	1000  	4.05308
# 77 	1000  	0.0527746	77 	20.6958  	0.0104667	1000  	0.924154  	32.154	77 	41 	6  	1000  	3.82861
# 78 	1000  	0.0115132	78 	0.194216 	0.0104667	1000  	0.0110398 	32.46 	78 	41 	7  	1000  	3.83567
# 79 	1000  	0.0117218	79 	0.337859 	0.0104667	1000  	0.0154914 	32.2  	79 	49 	7  	1000  	3.60777
# 80 	1000  	0.65593  	80 	322.181  	0.0104667	1000  	14.3935   	32.24 	80 	42 	6  	1000  	3.52738
# 81 	1000  	0.0773592	81 	32.9612  	0.0104647	1000  	1.47211   	32.002	81 	54 	6  	1000  	2.98027
# 82 	1000  	0.0112306	82 	0.233254 	0.0104667	1000  	0.010217  	32.06 	82 	39 	8  	1000  	1.85591
# 83 	1000  	0.0120205	83 	0.630672 	0.0104667	1000  	0.0279213 	32.19 	83 	42 	23 	1000  	1.83464
# 84 	1000  	4000.26  	84 	1e+06    	0.010457 	1000  	63118.9   	32.032	84 	42 	4  	1000  	2.87315
# 85 	1000  	2000.01  	85 	1e+06    	0.010457 	1000  	44676.6   	32.262	85 	39 	7  	1000  	3.00356
# 86 	1000  	0.0108471	86 	0.0980336	0.010457 	1000  	0.00399741	32.566	86 	39 	8  	1000  	2.39283
# 87 	1000  	0.0112226	87 	0.149193 	0.010457 	1000  	0.00730534	32.888	87 	46 	6  	1000  	3.271
# 88 	1000  	0.0376076	88 	7.23327  	0.010457 	1000  	0.384654  	33.098	88 	42 	5  	1000  	3.49348
# 89 	1000  	0.211263 	89 	99.5001  	0.010457 	1000  	4.44481   	33.344	89 	60 	5  	1000  	3.90201
# 90 	1000  	0.0115846	90 	0.169539 	0.010457 	1000  	0.00978091	33.782	90 	44 	10 	1000  	2.77677
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 3
#       1 # MU, LAMBDA = 100, 200
#       2 MU, LAMBDA = 500, 1000
# ----> 3 pop, logbook = eaMuPlusLambda(pop, toolbox, mu=MU, lambda_=LAMBDA,
#       4                                             cxpb=0.7, mutpb=0.3, ngen=100,
#       5                                             ray_evaluetors_pool=evaluators_pool,
#       6                                             stats=mstats, halloffame=hof)
#
# Cell In[26], line 52, in eaMuPlusLambda(population, toolbox, mu, lambda_, cxpb, mutpb, ngen, ray_evaluetors_pool, stats, halloffame, verbose)
#      50 invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#      51 # fitnesses = list(ray_evaluetors_pool.map(lambda evaluator, eval_ind: evaluator.eval.remote(eval_ind), invalid_ind))
# ---> 52 fitnesses = list(chain.from_iterable(ray_evaluetors_pool.map(lambda evaluator, chunk: evaluator.eval_batch.remote(chunk), toolbox.chunks(invalid_ind))))
#      53 for ind, fit in zip(invalid_ind, fitnesses):
#      54     ind.fitness.values = fit
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ray/util/actor_pool.py:113, in ActorPool.map.<locals>.get_generator()
#     111 def get_generator():
#     112     while self.has_next():
# --> 113         yield self.get_next()
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ray/util/actor_pool.py:309, in ActorPool.get_next(self, timeout, ignore_if_timedout)
#     305 if raise_timeout_after_ignore:
#     306     raise TimeoutError(
#     307         timeout_msg + ". The task {} has been ignored.".format(future)
#     308     )
# --> 309 return ray.get(future)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ray/_private/worker.py:2822, in get(object_refs, timeout)
#    2816     raise ValueError(
#    2817         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2818         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2819     )
#    2821 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2822 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2823 for i, value in enumerate(values):
#    2824     if isinstance(value, RayError):
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ray/_private/worker.py:904, in Worker.get_objects(self, object_refs, timeout, return_exceptions, skip_deserialization)
#     894         raise TypeError(
#     895             f"Attempting to call `get` on the value {object_ref}, "
#     896             "which is not an ray.ObjectRef."
#     897         )
#     899 timeout_ms = (
#     900     int(timeout * 1000) if timeout is not None and timeout != -1 else -1
#     901 )
#     902 data_metadata_pairs: List[
#     903     Tuple[ray._raylet.Buffer, bytes]
# --> 904 ] = self.core_worker.get_objects(
#     905     object_refs,
#     906     timeout_ms,
#     907 )
#     909 debugger_breakpoint = b""
#     910 for data, metadata in data_metadata_pairs:
#
# File python/ray/_raylet.pyx:3196, in ray._raylet.CoreWorker.get_objects()
#
# File python/ray/includes/common.pxi:83, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
# import deap


# evaluator = Evaluator2D(
#         Gamma2,
#         Gamma2_source,
#         f1,
#         f2,
#         mfs_data,
#         Gamma2.rf(mfs_data.collocation.theta),
#         pset,
#         heat_flux
#     )
# toolbox.register("evaluate", evaluator.eval)
# MU, LAMBDA = 500, 1000
# pop, logbook = deap.algorithms.eaMuPlusLambda(pop, toolbox, mu=MU, lambda_=LAMBDA,
#                                             cxpb=0.7, mutpb=0.3, ngen=100,
#                                             stats=mstats, halloffame=hof)

# %%
print("Best individual is: ", hof[0])
# Out:
# Best individual is:  cos(add(cos(cos(sin(sin(add(multiply(cos(multiply(expplusone(0.1255819766623446), sin(expplusone(sqrtabs(cos(s)))))), multiply(cos(cos(sqrtabs(multiply(0.27298309688180666, add(sin(s), add(sin(s), cos(cos(0.5944111496532088)))))))), 0.3656431950592871)), s))))), 0.5318002334363058))

# %%
from gpbr.tools.plot import plot_radial_boundaries_2d

fig_reconsructed = plot_radial_boundaries_2d(r1, toolbox.compile(expr=hof[0]), r2)
fig_reconsructed.savefig('./results/2d_2_reconstructed.png', dpi=300, transparent=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from gpbr.tools.plot import plot_evolution_stats

# Example usage
fig_fitness, fig_size, fig_correlation = plot_evolution_stats(
    logbook,
    title="GP Boundary Approximation"
)

# You can save each figure separately
fig_fitness.savefig('./results/2d_2_fitness_evolution.png', dpi=300)
fig_size.savefig('./results/2d_2_size_evolution.png', dpi=300)
fig_correlation.savefig('./results/2d_2_size_fitness_correlation.png', dpi=300)

# Or display them
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def plot_both_raw(exact_rfunc, approx_rfunc, n_theta=256, title="Exact vs. Approximate radial functions"):
    import matplotlib.pyplot as plt
    import numpy as np

    fig1, ax1 = plt.subplots(figsize=(10, 8))
    thetas = np.linspace(0, 2 * np.pi, n_theta)

    # Calculate radius values
    exact_rvals = exact_rfunc(thetas)
    approx_rvals = approx_rfunc(thetas)

    # If approx_rvals is a scalar, broadcast to array
    if np.isscalar(approx_rvals) or (isinstance(approx_rvals, np.ndarray) and approx_rvals.shape == ()):
        approx_rvals = np.ones_like(thetas) * approx_rvals

    # Exact solution - use a distinct blue
    ax1.plot(thetas, exact_rvals, color='#1E88E5', linestyle='--', linewidth=3,
             label='Exact Solution', alpha=0.9)

    # Approximation - use a vibrant purple
    ax1.plot(thetas, approx_rvals, color='#8E24AA', linewidth=3, label='Approximation')

    ax1.set_title(title)
    ax1.set_xlabel("Theta")
    ax1.set_ylabel("Radius")
    ax1.legend()
    return fig1

# %%
fig_raw = plot_both_raw(r1, toolbox.compile(expr=hof[0]))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s = np.linspace(0, 2*np.pi, 256)
exact_rvals = r1(s)
approx_rvals = toolbox.compile(expr=hof[0])(s)

# np.sqrt(integrate.trapezoid((exact_rvals-approx_rvals)**2, s)/integrate.trapezoid(exact_rvals, s))
np.sqrt(integrate.trapezoid((exact_rvals-approx_rvals)**2, s, axis=0)/integrate.trapezoid(exact_rvals**2, s,axis=0))
# Out:
# np.float64(0.015708831159755552)

# %%
approx_func = toolbox.compile(expr=hof[0])
np.sqrt(integrate.quad(lambda s: (r1(s) - approx_func(s))**2, 0, 2*np.pi)[0]/integrate.quad(lambda s: (approx_func(s))**2, 0, 2*np.pi)[0])
# Out:
# np.float64(0.01565550633436421)

# %%
ray.shutdown()
