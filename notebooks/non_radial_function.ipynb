# %%
import sys
import os
sys.path.append(os.path.abspath('..'))  # or the full path to the "project" directory
import numpy as np
import gpbr

# %%
def xf(t):
    return 0.4*(np.cos(t+0.3) + 0.1 * np.cos(3 * t))

def yf(t):
    return 0.4*(np.sin(t-0.05) + 0.3 * np.sin(3 * t))

# %%
from gpbr.direct.common.collocation import collocation_points_2d
coll = collocation_points_2d(32, startpoint=True)

# %%
from gpbr.direct.common.boundary import ParametricCurve
my_curve = ParametricCurve.from_parametric(coll, f1, f2)

# %%
import matplotlib
import matplotlib.pyplot as plt
def plot_radial(parametric_curve, n_theta=256):
    # Generate a closed non-radial curve
    t = np.linspace(0, 2 * np.pi, 500)
    xx = parametric_curve.xf(t)
    yy = parametric_curve.yf(t)
    # Plot the curve
    fig = plt.figure(figsize=(8, 6))
    plt.plot(xx, yy, color="green")
    plt.xlabel("X", fontsize=12)
    plt.ylabel("Y", fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.axis("equal")
    plt.legend()
    plt.show()
    fig.clf()

# %%
plot_radial(my_curve)
# Out:
# /var/folders/yp/sztpn13x2vq42vlgbb1zx8b80000gn/T/ipykernel_24806/4025512584.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a closed non-radial curve
t = np.linspace(0, 2 * np.pi, 500)
x = np.cos(t+0.3) + 0.1 * np.cos(3 * t)
y = np.sin(t-0.05) + 0.3 * np.sin(3 * t)

# Plot the curve
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="Closed Non-Radial Curve", color="green")
plt.title("Closed Non-Radial Curve (No Self-Intersections)", fontsize=14)
plt.xlabel("X", fontsize=12)
plt.ylabel("Y", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.axis("equal")
plt.legend()
plt.show()
